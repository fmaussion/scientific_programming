# %% [markdown]
# # Installing Python

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#On-linux" data-toc-modified-id="On-linux-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>On linux</a></span></li><li><span><a href="#On-windows" data-toc-modified-id="On-windows-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>On windows</a></span></li><li><span><a href="#Etc" data-toc-modified-id="Etc-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Etc</a></span></li></ul></div>

# %% [markdown]
# ## On linux

# %% [markdown]
# ## On windows

# %% [markdown]
# ## Etc
